# %%
nu_ = 0.89

# %%
nu_**2
# Out:
# 0.7921

# %%
Vin = 12.
Iin = 0.5

# %%
Vsup = 8.8
Isup = Vin/Vsup * Iin * nu_
Isup
# Out:
# 0.6068181818181818

# %%
Vout = 5.
Iout = Vsup/Vout * Isup * nu_
Iout
# Out:
# 0.95052

# %%
L = 0.158
W = 0.09
H = 0.06

A = 2 * (L * W + W * H + H * L)
A
# Out:
# 0.0582

# %%
L = 0.170
W = 0.14
H = 0.10

A = 2 * (L * W + W * H + H * L)
A
# Out:
# 0.10960000000000002
